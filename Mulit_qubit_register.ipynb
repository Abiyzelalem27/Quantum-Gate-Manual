# %%
import sys
import os

# Python path so notebook can find bell_state
sys.path.insert(0, os.path.abspath("src"))
                
import numpy as np  # arrays, linear algebra, numerical computing
import quantum_gate as qg #custom package(module)

# %% [markdown]
# Building gate operators on an n-qubit register
#
# To make our gates and registers more general, allowing us to use a register of $n$ qubits and apply single qubit gates to qubit $i$
#
# For a single qubit gate this means we have to build the matrix $\hat{U}^{(i)} = \mathbb{1} \otimes \dots \otimes \mathbb{1} \otimes \hat{U} \otimes \mathbb{1} \otimes \dots \otimes \mathbb{1} = \mathbb{1}_{2^{i}\times 2^{i}} \otimes \hat{U} \otimes \mathbb{1}_{2^{N-i-1}\times 2^{N-i-1}} $, where the subscript represents the size of the matrix. This operation applies the unitary $\hat{U}$ to the $i$th qubit without changing any other qubits.

# %%
U = qg.operators.U_one_gate(qg.operators.X, i=0, N=3) 
initial_state = np.zeros(2**3)
initial_state[0]=1 #|000>
final_state= U@initial_state 

print("final_state =", final_state)
# Out:
# final_state = [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %% [markdown]
# Building gate operators on an n-qubit register
#
# To make our gates and registers more general, allowing us to use a register of $n$ qubits and apply gates  entangling gates to qubits $i$ and $j$.
#
#  we have to build the matrix $\hat{U}^{(i,j
#  )} = \mathbb{1} \otimes \dots \otimes \mathbb{1} \otimes \hat{U} \otimes \mathbb{1} \otimes \dots \otimes \mathbb{1} = \mathbb{1}_{2^{i}\times 2^{i}} \otimes \hat{U} \otimes \mathbb{1}_{2^{j-i-1}\times 2^{j-i-1}} \hat{V} \otimes \mathbb{1}_{2^{N-j-1}\times 2^{N-j-1}} $, where the subscript represents the size of the matrix. This operation applies the unitary $\hat{U}$ to the $i$th qubit with changing any other qubits.

# %%
U = qg.operators.U_two_gates(qg.operators.X, qg.operators.Y, 1, 2, 3)
print("U =\n", U)
# Out:
# U =
#  [[0.+0.j 0.-0.j 0.+0.j 0.-1.j 0.+0.j 0.-0.j 0.+0.j 0.-0.j]
#  [0.+0.j 0.+0.j 0.+1.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.-1.j 0.+0.j 0.-0.j 0.+0.j 0.-0.j 0.+0.j 0.-0.j]
#  [0.+1.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.-0.j 0.+0.j 0.-0.j 0.+0.j 0.-0.j 0.+0.j 0.-1.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+1.j 0.+0.j]
#  [0.+0.j 0.-0.j 0.+0.j 0.-0.j 0.+0.j 0.-1.j 0.+0.j 0.-0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+1.j 0.+0.j 0.+0.j 0.+0.j]]

# %%
U = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 1, 2, 5)
print("U =\n", U)
# Out:
# U =
#  [[0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  ...
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]]

# %%
U = qg.operators.U_two_gates(qg.operators.Y, qg.operators.Y, 2, 1, 5)
print("U =\n", U)
# Out:
# U =
#  [[ 0.+0.j  0.+0.j  0.+0.j ... -0.+0.j -0.+0.j -0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ... -0.+0.j -0.+0.j -0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ... -0.+0.j -0.+0.j -0.+0.j]
#  ...
#  [ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]]

# %%
U = qg.operators.U_two_gates(qg.operators.H, qg.operators.H, 4, 2, 5)
print("U =\n", U)
# Out:
# U =
#  [[ 0.5+0.j  0.5+0.j  0. +0.j ...  0. +0.j  0. +0.j  0. +0.j]
#  [ 0.5+0.j -0.5+0.j  0. +0.j ... -0. +0.j  0. +0.j -0. +0.j]
#  [ 0. +0.j  0. +0.j  0.5+0.j ...  0. +0.j  0. +0.j  0. +0.j]
#  ...
#  [ 0. +0.j -0. +0.j  0. +0.j ...  0.5-0.j -0. +0.j  0. -0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j ... -0. +0.j -0.5+0.j -0.5+0.j]
#  [ 0. +0.j -0. +0.j  0. +0.j ...  0. -0.j -0.5+0.j  0.5-0.j]]

# %%
U = qg.operators.U_two_gates(qg.operators.H, qg.operators.T, 4, 2, 5)
print("U =\n", U)
# Out:
# U =
#  [[ 0.70710678+0.j   0.70710678+0.j   0.        +0.j  ...  0.        +0.j
#    0.        +0.j   0.        +0.j ]
#  [ 0.70710678+0.j  -0.70710678+0.j   0.        +0.j  ... -0.        +0.j
#    0.        +0.j  -0.        +0.j ]
#  [ 0.        +0.j   0.        +0.j   0.70710678+0.j  ...  0.        +0.j
#    0.        +0.j   0.        +0.j ]
#  ...
#  [ 0.        +0.j  -0.        +0.j   0.        +0.j  ... -0.5       -0.5j
#    0.        +0.j  -0.        +0.j ]
#  [ 0.        +0.j   0.        +0.j   0.        +0.j  ...  0.        +0.j
#    0.5       +0.5j  0.5       +0.5j]
#  [ 0.        +0.j  -0.        +0.j   0.        +0.j  ... -0.        +0.j
#    0.5       +0.5j -0.5       -0.5j]]

# %%
U = qg.operators.U_two_gates(qg.operators.T, qg.operators.H, 4, 2, 5)
print("U =\n", U)
# Out:
# U =
#  [[ 0.70710678+0.j   0.        +0.j   0.        +0.j  ...  0.        +0.j
#    0.        +0.j   0.        +0.j ]
#  [ 0.        +0.j   0.5       +0.5j  0.        +0.j  ...  0.        +0.j
#    0.        +0.j   0.        +0.j ]
#  [ 0.        +0.j   0.        +0.j   0.70710678+0.j  ...  0.        +0.j
#    0.        +0.j   0.        +0.j ]
#  ...
#  [ 0.        +0.j   0.        +0.j   0.        +0.j  ... -0.5       -0.5j
#   -0.        +0.j  -0.        +0.j ]
#  [ 0.        +0.j   0.        +0.j   0.        +0.j  ... -0.        +0.j
#   -0.70710678+0.j  -0.        +0.j ]
#  [ 0.        +0.j   0.        +0.j   0.        +0.j  ... -0.        +0.j
#   -0.        +0.j  -0.5       -0.5j]]

# %%
U = qg.operators.U_two_gates(qg.operators.S, qg.operators.T, 2, 3, 5)
print("U =\n", U)
# Out:
# U =
#  [[ 1.        +0.j          0.        +0.j          0.        +0.j
#   ...  0.        +0.j          0.        +0.j
#    0.        +0.j        ]
#  [ 0.        +0.j          1.        +0.j          0.        +0.j
#   ...  0.        +0.j          0.        +0.j
#    0.        +0.j        ]
#  [ 0.        +0.j          0.        +0.j          0.70710678+0.70710678j
#   ...  0.        +0.j          0.        +0.j
#    0.        +0.j        ]
#  ...
#  [ 0.        +0.j          0.        +0.j          0.        +0.j
#   ...  0.        +1.j          0.        +0.j
#    0.        +0.j        ]
#  [ 0.        +0.j          0.        +0.j          0.        +0.j
#   ...  0.        +0.j         -0.70710678+0.70710678j
#   -0.        +0.j        ]
#  [ 0.        +0.j          0.        +0.j          0.        +0.j
#   ...  0.        +0.j         -0.        +0.j
#   -0.70710678+0.70710678j]]

# %%
U = qg.operators.U_one_gate(qg.operators.H, 4, 8)
print("U =\n", U)
# Out:
# U =
#  [[ 0.70710678+0.j  0.        +0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j ...  0.        +0.j
#    0.        +0.j  0.        +0.j]
#  ...
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ... -0.70710678+0.j
#   -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ... -0.        +0.j
#   -0.70710678+0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j ... -0.        +0.j
#   -0.        +0.j -0.70710678+0.j]]

# %%
U = qg.operators.U_one_gate(qg.operators.X, 0, 2)
print("U =\n", U)
# Out:
# U =
#  [[0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]]

# %%
i=0
N=2 
psi = np.zeros(2**N)
psi[0] = 1
U = qg.operators.U_one_gate(qg.operators.X, i, N)
State_after = qg.operators.evolve(psi, U)
print("State_after =", State_after)
# Out:
# State_after = [0.+0.j 0.+0.j 1.+0.j 0.+0.j]

# %% [markdown]
# Density Operators
#
# A complete statistical description of a quantum state, pure or mixed, that supports noise, measurement, and subsystems.

# %%
i=0
N=2 

psi = np.zeros(2**N)
psi[0] = 1
rho0 = qg.operators.rho([psi], [1.0])
U = qg.operators.U_one_gate(qg.operators.X, i, N)
rho_after = qg.operators.evolve(rho0, U)
print("rho_after =\n", rho_after)
# Out:
# rho_after =
#  [[0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j]]
