# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from quantum_gate_package import I, S,T, Z, Y, X, H, P0, P1, U_N_qubits, U_one_gate, U_two_gates,rho,evolve

# %%
import numpy as np
CNOT= np.kron(P0, I) + np.kron(P1, X)
print(CNOT)
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]]

# %% [markdown]
# Case 2: Control = second qubit, Target = first qubit
#           CNOT1→0=I⊗P0+X⊗P1

# %%
import numpy as np
CNOT= np.kron(I, P0) + np.kron(X, P1)
print("CNOT:\n", CNOT)

#Example 
initial_state=np.array((1,0,0,0))
final_state=CNOT@initial_state
print("final_state:\n", final_state)
# Out:
# CNOT:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]]
# final_state:
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
import numpy as np
N=3
U_full = U_one_gate(H, 1, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
import numpy as np

U_full = U_one_gate(I, 1, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]

# %%
import numpy as np

U_full = U_one_gate(X, 1, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]

# %%
import numpy as np

U_full = U_two_gates(X, X, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]

# %%
import numpy as np

U_full = U_two_gates(X, H, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j
#    0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j
#    0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j]
# ...

# %%
import numpy as np

U_full = U_two_gates(H, I, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j
#    0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j]
# ...

# %%
import numpy as np

U_full = U_two_gates(H, I, 1, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
import numpy as np

U_full = U_two_gates(H, I, 2, 0, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(H, I, 0, 2, 3)
initial_state = np.zeros(2**N)
initial_state[6] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(H, I, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[0] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(H, H, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[0] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(X, X, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[0] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(I, H, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(I, H, 1, 1, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(I, H, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(X, X, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(X, X, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[5] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(X, X, 1, 1, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(X, X, 1, 2, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(X, X, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(X, H, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)

# %%
import numpy as np

U_full = U_two_gates(I, H, 2, 0, 3)
initial_state = np.zeros(2**N)
initial_state[6] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   -0.70710678+0.j -0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#   -0.        +0.j -0.70710678+0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#   -0.        +0.j -0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
ops = [H, H] 
U_full = U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[ 0.5+0.j  0.5+0.j  0.5+0.j  0.5+0.j]
#  [ 0.5+0.j -0.5+0.j  0.5+0.j -0.5+0.j]
#  [ 0.5+0.j  0.5+0.j -0.5+0.j -0.5+0.j]
#  [ 0.5+0.j -0.5+0.j -0.5+0.j  0.5-0.j]]
# Shape: (4, 4)

# %%
ops = [I, I] 
U_full = U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
# Shape: (4, 4)

# %%
ops = [X, X] 
U_full = U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j]]
# Shape: (4, 4)

# %%
ops = [X, H, I]  
U_full = U_N_qubits(ops)

print("Full 3-qubit operator:")
print(U_full)
print("Shape:", U_full.shape)
# Out:
# Full 3-qubit operator:
# [[ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
# ...

# %%
ops = [X, H, I, X, H, S, T] 
U_full = U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  ...
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]]
# Shape: (128, 128)

# %%
ops = [Z, Y, X, H, I, T] 
U_full = U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  ...
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]]
# Shape: (64, 64)

# %%
ops = [I, X, Z, Y, H, S, T, Y, H] 
U_full = U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -0.+0.j  0.+0.j ... -0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  ...
#  [ 0.+0.j -0.+0.j  0.+0.j ... -0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -0.+0.j  0.+0.j ... -0.+0.j  0.+0.j -0.+0.j]]
# Shape: (512, 512)
