# %%
import sys
import os

# Python path so notebook can find bell_state
sys.path.insert(0, os.path.abspath("src"))
                
import numpy as np  # arrays, linear algebra, numerical computing
import quantum_gate as qg #custom package(module)

# %%
CNOT= np.kron(qg.operators.P0, qg.operators.I) + np.kron(qg.operators.P1, qg.operators.X)
print("CNOT =\n", CNOT)
# Out:
# CNOT =
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]]

# %% [markdown]
# Case 2: Control = second qubit, Target = first qubit
#           CNOT1→0=I⊗P0+X⊗P1

# %%
CNOT= np.kron(qg.operators.I, qg.operators.P0) + np.kron(qg.operators.X, qg.operators.P1)
print("CNOT:\n", CNOT)

#Example 
initial_state=np.array((1,0,0,0))
final_state=CNOT@initial_state
print("final_state:\n", final_state)
# Out:
# CNOT:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]]
# final_state:
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
N=3
U_full = qg.operators.U_one_gate(qg.operators.H, 1, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full=\n", U_full)
print()
print("state= \n", state)
# Out:
# U_full=
#  [[ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
U_full = qg.operators.U_one_gate(qg.operators.I, 1, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]

# %%
U_full = qg.operators.U_one_gate(qg.operators.X, 1, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full=\n", U_full)
print()
print("state=\n", state)
# Out:
# U_full=
#  [[0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]]
#
# state=
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.H, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j
#    0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j
#    0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.H, qg.operators.I, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j
#    0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.H, qg.operators.I, 1, 2, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.H, qg.operators.I, 2, 0, 3)
initial_state = np.zeros(2**N)
initial_state[7] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j
#    0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j -0.        +0.j
#    0.70710678+0.j -0.70710678+0.j  0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.H, qg.operators.I, 0, 2, 3)
initial_state = np.zeros(2**N)
initial_state[6] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   -0.70710678+0.j -0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#   -0.        +0.j -0.70710678+0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#   -0.        +0.j -0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.H, qg.operators.I, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[0] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.H, qg.operators.H, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[0] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j]
#  [ 0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j]
#  [ 0.5+0.j  0. +0.j -0.5+0.j -0. +0.j  0.5+0.j  0. +0.j -0.5+0.j -0. +0.j]
#  [ 0. +0.j  0.5+0.j -0. +0.j -0.5+0.j  0. +0.j  0.5+0.j -0. +0.j -0.5+0.j]
#  [ 0.5+0.j  0. +0.j  0.5+0.j  0. +0.j -0.5+0.j -0. +0.j -0.5+0.j -0. +0.j]
#  [ 0. +0.j  0.5+0.j  0. +0.j  0.5+0.j -0. +0.j -0.5+0.j -0. +0.j -0.5+0.j]
#  [ 0.5+0.j  0. +0.j -0.5+0.j -0. +0.j -0.5+0.j -0. +0.j  0.5+0.j  0. +0.j]
#  [ 0. +0.j  0.5+0.j -0. +0.j -0.5+0.j -0. +0.j -0.5+0.j  0. +0.j  0.5+0.j]]
#
# state:
#  [0.5+0.j 0. +0.j 0.5+0.j 0. +0.j 0.5+0.j 0. +0.j 0.5+0.j 0. +0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[0] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.I, qg.operators.H, 1, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   -0.70710678+0.j -0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#   -0.        +0.j -0.70710678+0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#   -0.        +0.j -0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.I, qg.operators.H, 1, 1, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.I, qg.operators.H, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   -0.70710678+0.j -0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#   -0.        +0.j -0.70710678+0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#   -0.        +0.j -0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[5] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 1, 1, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 1, 2, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]]
#
# state:
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.X, 2, 2, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
#
# state:
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %%
U_full = qg.operators.U_two_gates(qg.operators.X, qg.operators.H, 0, 0, 3)
initial_state = np.zeros(2**N)
initial_state[2] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   -0.70710678+0.j -0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#   -0.        +0.j -0.70710678+0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#   -0.        +0.j -0.        +0.j -0.70710678+0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j
#   -0.        +0.j -0.        +0.j -0.        +0.j -0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
# ...

# %%
U_full = qg.operators.U_two_gates(qg.operators.I, qg.operators.H, 2, 0, 3)
initial_state = np.zeros(2**N)
initial_state[6] = 1

state= U_full @ initial_state
print("U_full:\n", U_full)
print()
print("state: \n", state)
# Out:
# U_full:
#  [[ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#   -0.70710678+0.j -0.        +0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#   -0.        +0.j -0.70710678+0.j -0.        +0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#   -0.        +0.j -0.        +0.j -0.70710678+0.j -0.        +0.j]
# ...

# %%
ops = [qg.operators.H, qg.operators.H] 
U_full = qg.operators.U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[ 0.5+0.j  0.5+0.j  0.5+0.j  0.5+0.j]
#  [ 0.5+0.j -0.5+0.j  0.5+0.j -0.5+0.j]
#  [ 0.5+0.j  0.5+0.j -0.5+0.j -0.5+0.j]
#  [ 0.5+0.j -0.5+0.j -0.5+0.j  0.5-0.j]]
# Shape: (4, 4)

# %%
ops = [qg.operators.I, qg.operators.I] 
U_full = qg.operators.U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]]
# Shape: (4, 4)

# %%
ops = [qg.operators.X, qg.operators.X] 
U_full = qg.operators.U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j]]
# Shape: (4, 4)

# %%
ops = [qg.operators.X, qg.operators.H, qg.operators.I]  
U_full = qg.operators.U_N_qubits(ops)

print("Full 3-qubit operator:")
print(U_full)
print("Shape:", U_full.shape)
# Out:
# Full 3-qubit operator:
# [[ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j]
#  [ 0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j
#    0.        +0.j  0.70710678+0.j -0.        +0.j -0.70710678+0.j]
#  [ 0.70710678+0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.70710678+0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j  0.        +0.j -0.70710678+0.j -0.        +0.j
#    0.        +0.j  0.        +0.j -0.        +0.j -0.        +0.j]
# ...

# %%
ops = [qg.operators.X, qg.operators.H, qg.operators.I, qg.operators.X, qg.operators.H, qg.operators.S, qg.operators.T] 
U_full = qg.operators.U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  ...
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]]
# Shape: (128, 128)

# %%
ops = [qg.operators.Z, qg.operators.Y, qg.operators.X, qg.operators.H, qg.operators.I, qg.operators.T] 
U_full = qg.operators.U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  ...
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j ... 0.+0.j 0.+0.j 0.+0.j]]
# Shape: (64, 64)

# %%
ops = [qg.operators.I, qg.operators.X, qg.operators.Z, qg.operators.Y, qg.operators.H, qg.operators.S, qg.operators.T, qg.operators.Y, qg.operators.H] 
U_full = qg.operators.U_N_qubits(ops)

print("N_operator:\n", U_full)
print("Shape:", U_full.shape)
# Out:
# N_operator:
#  [[ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -0.+0.j  0.+0.j ... -0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  ...
#  [ 0.+0.j -0.+0.j  0.+0.j ... -0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j ...  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -0.+0.j  0.+0.j ... -0.+0.j  0.+0.j -0.+0.j]]
# Shape: (512, 512)
